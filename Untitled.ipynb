# %%
'''
PyPower Projects
Emotion Detection Using AI
'''

#USAGE : python test.py

from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
classifier =load_model('./Emotion_Detection.h5')

class_labels = ['Angry','Happy','Neutral','Sad','Surprise']

cap = cv2.VideoCapture(0)



while True:
    # Grab a single frame of video
    ret, frame = cap.read()
    labels = []
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h,x:x+w]
        roi_gray = cv2.resize(roi_gray,(48,48),interpolation=cv2.INTER_AREA)


        if np.sum([roi_gray])!=0:
            roi = roi_gray.astype('float')/255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi,axis=0)

        # make a prediction on the ROI, then lookup the class

            preds = classifier.predict(roi)[0]
            print("\nprediction = ",preds)
            label=class_labels[preds.argmax()]
            print("\nprediction max = ",preds.argmax())
            print("\nlabel = ",label)
            label_position = (x,y)
            cv2.putText(frame,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        else:
            cv2.putText(frame,'No Face Found',(20,60),cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        print("\n\n")
    cv2.imshow('Emotion Detector',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 1s/step
#
# prediction =  [0.12824512 0.0128679  0.5984143  0.24351984 0.01695281]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 48ms/step
#
# prediction =  [0.05432193 0.00869979 0.8390429  0.08953939 0.00839599]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 50ms/step
#
# prediction =  [0.05236598 0.00959439 0.84737444 0.08304782 0.0076173 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 49ms/step
#
# prediction =  [0.05137358 0.00995667 0.8480239  0.08286034 0.0077855 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.08350237 0.01500916 0.7475987  0.14156796 0.01232186]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 24ms/step
#
# prediction =  [0.07793526 0.01349734 0.7667548  0.13054995 0.01126267]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 57ms/step
#
# prediction =  [0.08711986 0.01558638 0.735328   0.1496023  0.01236343]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 48ms/step
#
# prediction =  [0.07453477 0.01387539 0.77612627 0.12384973 0.01161389]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 49ms/step
#
# prediction =  [0.07791736 0.01613722 0.76091415 0.13082626 0.01420503]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 27ms/step
#
# prediction =  [0.10360502 0.01834986 0.6572628  0.20264295 0.01813942]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 33ms/step
#
# prediction =  [0.06691314 0.01104384 0.79696786 0.11185848 0.01321665]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 31ms/step
#
# prediction =  [0.0681003  0.01309796 0.7856269  0.11800507 0.01516974]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.07137222 0.01425332 0.77373326 0.12488845 0.01575271]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.07992953 0.01917293 0.740045   0.13876687 0.02208559]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 23ms/step
#
# prediction =  [0.08113661 0.01900728 0.73550224 0.14209111 0.02226276]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 27ms/step
#
# prediction =  [0.08868968 0.01875738 0.7173768  0.15254681 0.02262936]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 24ms/step
#
# prediction =  [0.08203837 0.0171259  0.73485005 0.14344731 0.0225383 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 28ms/step
#
# prediction =  [0.1657968  0.0243733  0.35766286 0.41777027 0.03439675]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 44ms/step
#
# prediction =  [0.1522289  0.02074339 0.30422494 0.50774515 0.01505766]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 30ms/step
#
# prediction =  [0.1186296  0.02191088 0.60248077 0.22906825 0.02791051]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 27ms/step
#
# prediction =  [0.09869041 0.01873375 0.6856468  0.17587715 0.02105185]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 27ms/step
#
# prediction =  [0.11840359 0.01863699 0.6305707  0.21123165 0.02115702]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.10024607 0.02120016 0.6787163  0.17614552 0.02369198]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 33ms/step
#
# prediction =  [0.10633717 0.01954682 0.6439544  0.20254022 0.02762135]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 39ms/step
#
# prediction =  [0.11457399 0.01863445 0.624083   0.22132784 0.02138064]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 31ms/step
#
# prediction =  [0

#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 33ms/step
#
# prediction =  [0.06674968 0.09450216 0.67926556 0.13184944 0.02763315]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.07351669 0.06761167 0.6837311  0.1462813  0.0288592 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 32ms/step
#
# prediction =  [0.07054934 0.05160397 0.7149613  0.13609564 0.02678979]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 24ms/step
#
# prediction =  [0.13119923 0.08800241 0.36013156 0.3706551  0.05001172]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 30ms/step
#
# prediction =  [0.09472221 0.06649715 0.54523915 0.2708401  0.02270137]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 27ms/step
#
# prediction =  [0.10686169 0.0684855  0.37356538 0.41824806 0.03283936]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.11523747 0.0608969  0.46372744 0.3201529  0.03998522]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.15537988 0.10698493 0.2628748  0.44042718 0.03433316]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 31ms/step
#
# prediction =  [0.13063705 0.12335661 0.23154241 0.49248996 0.02197394]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 36ms/step
#
# prediction =  [0.12926327 0.04918642 0.38918233 0.4100875  0.02228045]
#
# prediction max =  3
#
# label =  Sad
#
#
#
# 1/1 [==============================] - 0s 27ms/step
#
# prediction =  [0.12568612 0.02792925 0.53894055 0.26692045 0.04052366]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 33ms/step
#
# prediction =  [0.11052425 0.02346681 0.6176857  0.21544442 0.03287887]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 26ms/step
#
# prediction =  [0.13707112 0.02598241 0.49870226 0.2994169  0.03882725]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 25ms/step
#
# prediction =  [0.09615497 0.02500618 0.67071104 0.1811043  0.02702344]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 33ms/step
#
# prediction =  [0.05085619 0.72475284 0.11818197 0.09304859 0.01316043]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 31ms/step
#
# prediction =  [0.06634863 0.6465145  0.14753707 0.11918964 0.02041018]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 39ms/step
#
# prediction =  [0.04090942 0.7567828  0.11159538 0.07743552 0.01327689]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 26ms/step
#
# prediction =  [0.03036405 0.8026611  0.09883253 0.05803295 0.01010939]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 29ms/step
#
# prediction =  [0.08203163 0.52202916 0.224497   0.15556197 0.01588019]
#
# prediction max =  1
#
# label =  Happy
#
#
#
# 1/1 [==============================] - 0s 31ms/step
#
# prediction =  [0.12948595 0.07867112 0.44135293 0.31327817 0.03721181]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 30ms/step
#
# prediction =  [0.12179347 0.05003926 0.5285855  0.2502218  0.04936007]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
# 1/1 [==============================] - 0s 37ms/step
#
# prediction =  [0.10777503 0.03002379 0.60947937 0.2156568  0.03706512]
#
# prediction max =  2
#
# label =  Neutral

# %%
from flask import Flask, render_template, Response
from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

app = Flask(__name__)

face_classifier = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
classifier = load_model('./Emotion_Detection.h5')

class_labels = ['Angry', 'Happy', 'Neutral', 'Sad', 'Surprise']

def generate_frames():
    cap = cv2.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        labels = []
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_classifier.detectMultiScale(gray, 1.3, 5)

        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
            roi_gray = gray[y:y + h, x:x + w]
            roi_gray = cv2.resize(roi_gray, (48, 48), interpolation=cv2.INTER_AREA)

            if np.sum([roi_gray]) != 0:
                roi = roi_gray.astype('float') / 255.0
                roi = img_to_array(roi)
                roi = np.expand_dims(roi, axis=0)

                preds = classifier.predict(roi)[0]
                label = class_labels[preds.argmax()]
                label_position = (x, y)
                cv2.putText(frame, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
            else:
                cv2.putText(frame, 'No Face Found', (20, 60), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)

        ret, buffer = cv2.imencode('.jpg', frame)
        frame = buffer.tobytes()
        yield (b'--frame\r\n'
               b'Content-Type: image/jpeg\r\n\r\n' + frame + b'\r\n')

    cap.release()

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/video_feed')
def video_feed():
    return Response(generate_frames(), mimetype='multipart/x-mixed-replace; boundary=frame')

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\Soumyajit\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
